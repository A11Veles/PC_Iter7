# %% [markdown]
# # Import packages

# %%
import pandas as pd
from teradataml import *
import ast
import json
import torch
from teradataml.dataframe.copy_to import copy_to_sql
from transformers.generation import GenerationMixin

from modules.db import TeradataDatabase
from modules.models import( 
    OpusTranslationModelConfig, 
                        OpusTranslationModel, 
                        SentenceEmbeddingConfig, 
                        SentenceEmbeddingModel, 
)
from utils import clean_text, load_embedding_model, unicode_clean, load_translation_model
from constants import (
     GPC_PATH
)

# %% [markdown]
# ## Connect to database

# %%
td_db = TeradataDatabase()
td_db.connect()

# %%
tdf = td_db.execute_query("Select * from demo_user.gpc_orig")
df = pd.DataFrame(tdf)

# %%
df.head()

# %% [markdown]
# ### Remvoing un-neccesary columns

# %%
query = """
ALTER TABLE demo_user.gpc_orig 
DROP SegmentCode,
DROP FamilyCode,
DROP ClassCode,
Drop BrickCode,
DROP AttributeCode,
DROP AttributeTitle,
DROP AttributeDefinition,
DROP AttributeValueCode,
DROP AttributeValueTitle,
DROP AttributeValueDefinition;
"""

# %%
tdf = td_db.execute_query(query)

# %% [markdown]
# ### Cleaning the GPC Columns

# %%
cleaning_query = """
UPDATE demo_user.gpc_orig
SET SegmentTitle = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(SegmentTitle, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    SegmentDefinition = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(SegmentDefinition, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    FamilyTitle = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(FamilyTitle, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    FamilyDefinition = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(FamilyDefinition, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    ClassTitle = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(ClassTitle, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    ClassDefinition = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(ClassDefinition, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    BrickTitle = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(BrickTitle, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    BrickDefinition_Includes = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(BrickDefinition_Includes, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' '))),
    BrickDefinition_Excludes = LOWER(TRIM(
                          REGEXP_REPLACE(
                            REGEXP_REPLACE(
                              REGEXP_REPLACE(BrickDefinition_Excludes, '[[:digit:]]+', ''), 
                              '[-_/\\|]', ' '),                              
                            '[[:punct:]]', ' ')));

"""

# %%
tdf = td_db.execute_query(cleaning_query)

# %% [markdown]
# ## Disconnect

# %%
td_db.disconnect()

# %%
gpc_df = pd.read_excel(GPC_PATH)
gpc_df.head()
# Out:
#    SegmentCode            SegmentTitle  \
# 0     70000000  Arts/Crafts/Needlework
# 1     70000000  Arts/Crafts/Needlework
# 2     70000000  Arts/Crafts/Needlework
# 3     70000000  Arts/Crafts/Needlework
# 4     70000000  Arts/Crafts/Needlework
#
#                                    SegmentDefinition  FamilyCode  \
# 0  All products that are used to any creative act...    70010000
# 1  All products that are used to any creative act...    70010000
# 2  All products that are used to any creative act...    70010000
# 3  All products that are used to any creative act...    70010000
# 4  All products that are used to any creative act...    70010000
#
#                        FamilyTitle  \
# 0  Arts/Crafts/Needlework Supplies
# 1  Arts/Crafts/Needlework Supplies
# 2  Arts/Crafts/Needlework Supplies
# 3  Arts/Crafts/Needlework Supplies
# 4  Arts/Crafts/Needlework Supplies
#
#                                     FamilyDefinition  ClassCode  \
# 0  All products that are used to any creative act...   70010100
# 1  All products that are used to any creative act...   70010100
# 2  All products that are used to any creative act...   70010100
# 3  All products that are used to any creative act...   70010100
# 4  All products that are used to any creative act...   70010100
#
#                           ClassTitle  \
# 0  Artists Painting/Drawing Supplies
# 1  Artists Painting/Drawing Supplies
# 2  Artists Painting/Drawing Supplies
# 3  Artists Painting/Drawing Supplies
# 4  Artists Painting/Drawing Supplies
#
#                                      ClassDefinition  BrickCode  \
# 0  Includes any products that may be described/ob...   10001674
# 1  Includes any products that may be described/ob...   10001674
# 2  Includes any products that may be described/ob...   10001674
# 3  Includes any products that may be described/ob...   10001674
# 4  Includes any products that may be described/ob...   10001674
#
#                     BrickTitle  \
# 0  Artists Brushes/Applicators
# 1  Artists Brushes/Applicators
# 2  Artists Brushes/Applicators
# 3  Artists Brushes/Applicators
# 4  Artists Brushes/Applicators
#
#                             BrickDefinition_Includes  \
# 0  Includes any products that can be described/ob...
# 1  Includes any products that can be described/ob...
# 2  Includes any products that can be described/ob...
# 3  Includes any products that can be described/ob...
# 4  Includes any products that can be described/ob...
#
#                             BrickDefinition_Excludes  AttributeCode  \
# 0  Specifically excludes Household Paint Brushes ...     20001337.0
# 1  Specifically excludes Household Paint Brushes ...     20001337.0
# 2  Specifically excludes Household Paint Brushes ...     20001337.0
# 3  Specifically excludes Household Paint Brushes ...     20001337.0
# 4  Specifically excludes Household Paint Brushes ...     20001337.0
#
#                      AttributeTitle  \
# 0  Type of Artists Brush/Applicator
# 1  Type of Artists Brush/Applicator
# 2  Type of Artists Brush/Applicator
# 3  Type of Artists Brush/Applicator
# 4  Type of Artists Brush/Applicator
#
#                                  AttributeDefinition  AttributeValueCode  \
# 0  Indicates, with reference to the product brand...          30008491.0
# 1  Indicates, with reference to the product brand...          30008492.0
# 2  Indicates, with reference to the product brand...          30008493.0
# 3  Indicates, with reference to the product brand...          30008494.0
# 4  Indicates, with reference to the product brand...          30008495.0
#
#                AttributeValueTitle AttributeValueDefinition
# 0  ARTISTS BLENDER/FINISHING BRUSH                      NaN
# 1        ARTISTS CALLIGRAPHY BRUSH                      NaN
# 2               ARTISTS FLAT BRUSH                      NaN
# 3              ARTISTS ROUND BRUSH                      NaN
# 4       ARTISTS SCRIPT LINER BRUSH                      NaN

# %%
cols_to_keep = [
    "SegmentTitle", "SegmentDefinition", 
    "FamilyTitle", "FamilyDefinition", 
    "ClassTitle", "ClassDefinition", 
    "BrickTitle", "BrickDefinition_Includes", "BrickDefinition_Excludes"
]

gpc_df = gpc_df[cols_to_keep]
gpc_df.head()
# Out:
#              SegmentTitle                                  SegmentDefinition  \
# 0  Arts/Crafts/Needlework  All products that are used to any creative act...
# 1  Arts/Crafts/Needlework  All products that are used to any creative act...
# 2  Arts/Crafts/Needlework  All products that are used to any creative act...
# 3  Arts/Crafts/Needlework  All products that are used to any creative act...
# 4  Arts/Crafts/Needlework  All products that are used to any creative act...
#
#                        FamilyTitle  \
# 0  Arts/Crafts/Needlework Supplies
# 1  Arts/Crafts/Needlework Supplies
# 2  Arts/Crafts/Needlework Supplies
# 3  Arts/Crafts/Needlework Supplies
# 4  Arts/Crafts/Needlework Supplies
#
#                                     FamilyDefinition  \
# 0  All products that are used to any creative act...
# 1  All products that are used to any creative act...
# 2  All products that are used to any creative act...
# 3  All products that are used to any creative act...
# 4  All products that are used to any creative act...
#
#                           ClassTitle  \
# 0  Artists Painting/Drawing Supplies
# 1  Artists Painting/Drawing Supplies
# 2  Artists Painting/Drawing Supplies
# 3  Artists Painting/Drawing Supplies
# 4  Artists Painting/Drawing Supplies
#
#                                      ClassDefinition  \
# 0  Includes any products that may be described/ob...
# 1  Includes any products that may be described/ob...
# 2  Includes any products that may be described/ob...
# 3  Includes any products that may be described/ob...
# 4  Includes any products that may be described/ob...
#
#                     BrickTitle  \
# 0  Artists Brushes/Applicators
# 1  Artists Brushes/Applicators
# 2  Artists Brushes/Applicators
# 3  Artists Brushes/Applicators
# 4  Artists Brushes/Applicators
#
#                             BrickDefinition_Includes  \
# 0  Includes any products that can be described/ob...
# 1  Includes any products that can be described/ob...
# 2  Includes any products that can be described/ob...
# 3  Includes any products that can be described/ob...
# 4  Includes any products that can be described/ob...
#
#                             BrickDefinition_Excludes
# 0  Specifically excludes Household Paint Brushes ...
# 1  Specifically excludes Household Paint Brushes ...
# 2  Specifically excludes Household Paint Brushes ...
# 3  Specifically excludes Household Paint Brushes ...
# 4  Specifically excludes Household Paint Brushes ...

# %%
copy_to_sql(gpc_df, "GPC_Labels", "demo_user", if_exists="replace")

# %%
gpc_df["Segment"] = gpc_df["SegmentTitle"].astype(str) + " - " + gpc_df["SegmentDefinition"].astype(str)
gpc_df["Family"]  = gpc_df["FamilyTitle"].astype(str)   + " - " + gpc_df["FamilyDefinition"].astype(str)
gpc_df["Class"]   = gpc_df["ClassTitle"].astype(str)    + " - " + gpc_df["ClassDefinition"].astype(str)
gpc_df["Brick"]   = gpc_df["BrickTitle"].astype(str)    + " - " + gpc_df["BrickDefinition_Includes"].astype(str)

# Keep only the new concatenated columns
gpc_df = gpc_df[["Segment", "Family", "Class", "Brick"]]

# %%
gpc_df.head()
# Out:
#                                              Segment  \
# 0  Arts/Crafts/Needlework - All products that are...
# 1  Arts/Crafts/Needlework - All products that are...
# 2  Arts/Crafts/Needlework - All products that are...
# 3  Arts/Crafts/Needlework - All products that are...
# 4  Arts/Crafts/Needlework - All products that are...
#
#                                               Family  \
# 0  Arts/Crafts/Needlework Supplies - All products...
# 1  Arts/Crafts/Needlework Supplies - All products...
# 2  Arts/Crafts/Needlework Supplies - All products...
# 3  Arts/Crafts/Needlework Supplies - All products...
# 4  Arts/Crafts/Needlework Supplies - All products...
#
#                                                Class  \
# 0  Artists Painting/Drawing Supplies - Includes a...
# 1  Artists Painting/Drawing Supplies - Includes a...
# 2  Artists Painting/Drawing Supplies - Includes a...
# 3  Artists Painting/Drawing Supplies - Includes a...
# 4  Artists Painting/Drawing Supplies - Includes a...
#
#                                                Brick
# 0  Artists Brushes/Applicators - Includes any pro...
# 1  Artists Brushes/Applicators - Includes any pro...
# 2  Artists Brushes/Applicators - Includes any pro...
# 3  Artists Brushes/Applicators - Includes any pro...
# 4  Artists Brushes/Applicators - Includes any pro...

# %%
def load_gpc():
    gpc_df = pd.read_excel(GPC_PATH)
    cols_to_keep = [
    "SegmentTitle", "SegmentDefinition", 
    "FamilyTitle", "FamilyDefinition", 
    "ClassTitle", "ClassDefinition", 
    "BrickTitle", "BrickDefinition_Includes"
    ]

    gpc_df = gpc_df[cols_to_keep]

    return gpc_df

# %%
train_df = pd.read_csv('../data/correctly_matched_mapped_gpc.csv')
test2_df = pd.read_csv('../data/validated_actually_labeled_test_dataset.csv')
gpc_df = load_gpc()

segment_map = (gpc_df["SegmentTitle"].astype(str) + " - " + gpc_df["SegmentDefinition"].astype(str)).to_dict()
family_map  = (gpc_df["FamilyTitle"].astype(str)  + " - " + gpc_df["FamilyDefinition"].astype(str)).to_dict()
class_map   = (gpc_df["ClassTitle"].astype(str)   + " - " + gpc_df["ClassDefinition"].astype(str)).to_dict()
brick_map   = (gpc_df["BrickTitle"].astype(str)   + " - " + gpc_df["BrickDefinition_Includes"].astype(str)).to_dict()

if "segment" in train_df.columns:
    train_df["segment"] = train_df["segment"].map(segment_map).fillna(train_df["segment"])
if "family" in train_df.columns:
    train_df["family"] = train_df["family"].map(family_map).fillna(train_df["family"])
if "class" in train_df.columns:
    train_df["class"] = train_df["class"].map(class_map).fillna(train_df["class"])
if "brick" in train_df.columns:
    train_df["brick"] = train_df["brick"].map(brick_map).fillna(train_df["brick"])

if "predicted_segment" in test2_df.columns:
    test2_df["predicted_segment"] = test2_df["predicted_segment"].map(segment_map).fillna(test2_df["predicted_segment"])
if "predicted_family" in test2_df.columns:
    test2_df["predicted_family"] = test2_df["predicted_family"].map(family_map).fillna(test2_df["predicted_family"])
if "predicted_class" in test2_df.columns:
    test2_df["predicted_class"] = test2_df["predicted_class"].map(class_map).fillna(test2_df["predicted_class"])
if "predicted_brick" in test2_df.columns:
    test2_df["predicted_brick"] = test2_df["predicted_brick"].map(brick_map).fillna(test2_df["predicted_brick"])

# %%
train_df.head()
# Out:
#    new_id  id                                 product_name        segment  \
# 0       1   0                   WESSON Vegetable Oil 1 GAL  Food/Beverage
# 1       2   2     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER  Food/Beverage
# 2       3   3  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI  Food/Beverage
# 3       4  10                 CAMPBELL'S SOUP BEAN AND HAM  Food/Beverage
# 4       5  12                    PREGO SAUCES TOMATO BASIL  Food/Beverage
#
#                      family                                         class  \
# 0          Oils/Fats Edible                              Oils/Fats Edible
# 1  Prepared/Preserved Foods  Prepared/Preserved Foods - Liquid/Sauce/Soup
# 2  Prepared/Preserved Foods  Prepared/Preserved Foods - Liquid/Sauce/Soup
# 3  Prepared/Preserved Foods  Prepared/Preserved Foods - Liquid/Sauce/Soup
# 4  Prepared/Preserved Foods  Prepared/Preserved Foods - Liquid/Sauce/Soup
#
#                                  brick
# 0            Oils/Fats Edible - Liquid
# 1   Soup - Ready to Eat (Shelf Stable)
# 2   Soup - Ready to Eat (Shelf Stable)
# 3   Soup - Ready to Eat (Shelf Stable)
# 4  Sauce - Ready to Eat (Shelf Stable)

# %%
test2_df.head()
